# %%
##for nucleotide sequences

import pandas as pd
import os

import stat
import statistics
import numpy as np
import timeit
from Bio import SeqIO
import subprocess
import sys
import pandas as pd
import os

MAIN_DIR='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/pangenome_alignments/'
path='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/alleleome/'


#######for core genes
df=pd.read_csv(path + 'df_pangene_summary_v2.csv')
core_gene_list = (df['pangenome_class_2'].eq('Core').groupby(df['Gene']).any()).pipe(lambda x:x.index[x].tolist())

#####for demo run
#nuc_query_list=[name for name in os.listdir(MAIN_DIR) if os.path.isdir(os.path.join(MAIN_DIR, name))]
#print(nuc_query_list)
#print(len(nuc_query_list))
#######


genes_df = pd.DataFrame()


for k in core_gene_list:
    print(k)
    s=0
    i=0
    nuc_allele_file = MAIN_DIR + k + '/input/'
    nuc_file=  nuc_allele_file + 'pangenes.fna'
    f=open(nuc_file,'r+')
    for seq_record in SeqIO.parse(nuc_file, "fasta"):
        g_id=seq_record.id
        l_gene=len(seq_record)
        print(l_gene)
        i=i+1
        s=s+l_gene
        print(i)
        print(s)
    df=pd.DataFrame.from_dict({
    "Gene":k,
    "Number_of_strains":i,
    }, orient='index')
    df=df.T
    genes_df=pd.concat([df,genes_df])
    print(genes_df)
    #print(statistics.stdev(gene_length, mean))
    genes_df.to_csv(os.path.join(path,'Genes_nuc_length_number_of_strains.csv'))

# %%
import numpy as np
import pandas as pd
import os


#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_paragasseri/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_paragasseri/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lacticaseibacillus_rhamnosus/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lacticaseibacillus_rhamnosus/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Weissella_cibaria/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Weissella_cibaria/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_crispatus/pangenome_alignments/'
#path= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_crispatus/alleleome/'

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Oenococcus_oeni/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Oenococcus_oeni/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Pediococcus_pentosaceus/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Pediococcus_pentosaceus/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Pediococcus_acidilactici/pangenome_alignments/'
#path= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Pediococcus_acidilactici/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_acidophilus/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_acidophilus/alleleome/' 
 
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Ligilactobacillus_ruminis/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Ligilactobacillus_ruminis/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lacticaseibacillus_paracasei/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lacticaseibacillus_paracasei/alleleome/'

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_gasseri/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_gasseri/alleleome/' 
 
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Levilactobacillus_brevis/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Levilactobacillus_brevis/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_delbrueckii/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_delbrueckii/alleleome/'

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Latilactobacillus_sakei/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Latilactobacillus_sakei/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lentilactobacillus_parabuchneri/pangenome_alignments/'
#path= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lentilactobacillus_parabuchneri/alleleome/'
 
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Limosilactobacillus_reuteri/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Limosilactobacillus_reuteri/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Leuconostoc_inhae/pangenome_alignments/'
#path= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Leuconostoc_inhae/alleleome/'
 
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Leuconostoc_mesenteroides/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Leuconostoc_mesenteroides/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_johnsonii/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_johnsonii/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactiplantibacillus_pentosus/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactiplantibacillus_pentosus/alleleome/'
 
MAIN_DIR='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/pangenome_alignments/'
path='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/alleleome/'

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Ligilactobacillus_salivarius/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Ligilactobacillus_salivarius/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_iners/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_iners/alleleome/'

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Weissella_confusa/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Weissella_confusa/alleleome/' 
 
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Limosilactobacillus_fermentum/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Limosilactobacillus_fermentum/alleleome/'


df=pd.read_csv(path +'Genes_nuc_length_number_of_strains.csv')

print("The total number of genes is",df.shape)
#calculate the 5% based on total number of strain
df_genes=df[df.Number_of_strains < 2].index
print(df_genes)
print("The genes present in less than 5% ",df_genes.shape)


df.drop(df_genes, inplace=True)
df
print("The genes present above 5% ",df.shape)

df.to_csv(os.path.join(path,'Final_nuc_genes_present_in_above_5_percent_of_strains.csv'))

# %%
import pandas as pd
import os

import stat
import statistics
import numpy as np
import timeit
from Bio import SeqIO
import subprocess
import sys
import pandas as pd



####cloud path

MAIN_DIR='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/pangenome_alignments/'
path='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/alleleome/'

#######for core genes
df=pd.read_csv(path +'df_pangene_summary_v2.csv')
core_gene_list = (df['pangenome_class_2'].eq('Core').groupby(df['Gene']).any()).pipe(lambda x:x.index[x].tolist())



genes_df = pd.DataFrame()

for k in core_gene_list:
    print(k)
    s=0
    gene_length=[]
    i=0
    nuc_allele_file = MAIN_DIR + k + '/input/'
    nuc_file=  nuc_allele_file + 'pangenes.fna'

    f=open(nuc_file,'r+')
    for seq_record in SeqIO.parse(nuc_file, "fasta"):
        g_id=seq_record.id
        #print(seq_record.seq)
        l_gene=len(seq_record)
        #print(l_gene)
        gene_length.append(l_gene)
        i=i+1
        s=s+l_gene
        df=pd.DataFrame.from_dict({
        "Gene":k,
        "Locus_tag":g_id,    
        "Length_of_allele":l_gene,
        #"Mean_length":mean(s),
    
        }, orient='index')
        df=df.T
        genes_df=pd.concat([df,genes_df])
        #print(genes_df)
        #print("mean length is", mean)
        #print(statistics.stdev(gene_length, mean))
        genes_df.to_csv(os.path.join(path,'Genes_nuc_length_of_alleles.csv'))

# %%
import pandas as pd
import os
MAIN_DIR='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/pangenome_alignments/'
path='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/alleleome/'

#######for core genes


df=pd.read_csv(path + 'Genes_nuc_length_of_alleles.csv')
df.shape
#df['std'] = df.groupby(['Gene','Length_of_allele']).transform('std')
df
new_df = df.groupby(['Gene']).Length_of_allele.agg({'mean','std'})
new_df['mean']=new_df['mean'].apply(lambda x:round(x,0))
new_df['std']=new_df['std'].apply(lambda x:round(x,2))


new_df.to_csv(os.path.join(path,'core_nuc_alleles_with_mean_std.csv'))
df = df.merge(new_df, left_on=['Gene'], right_index=True)
#df
df.to_csv(os.path.join(path,'core_nuc_alleles_with_locus_mean_std.csv'))
df

# %%
import pandas as pd
import os
MAIN_DIR='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/pangenome_alignments/'
path='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/alleleome/'

df1=pd.read_csv(path +'core_nuc_alleles_with_locus_mean_std.csv')
df1
df1['mean_2std']=(df1['mean']- 2*df1['std'])
df1

df2=df1[df1.Length_of_allele < df1.mean_2std]
df2.to_csv(os.path.join(path,'core_alleles_with_length_less_than_2std_less_than_mean_length.csv'))
df2

# %%
import glob
from webbrowser import get
from Bio.Blast import NCBIXML
import pandas as pd
from Bio.Seq import Seq
import os
from Bio import SeqIO
import sys



#####cloud path

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_paragasseri/pangenome_alignments/'

MAIN_DIR='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/pangenome_alignments/'
path='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/alleleome/'


df=pd.read_csv(path + 'core_alleles_with_length_less_than_2std_less_than_mean_length.csv')

print(df.head())

gene_locus_list=df['Gene'].to_list()
gene_locus_list=set(gene_locus_list)
#print(gene_locus_list)
locus_list=df['Locus_tag'].to_list()


i=0
sequences=[]

for s in gene_locus_list:
    print(s)
    aa_allele_path = MAIN_DIR + s + '/input/' 
    aa_file=  aa_allele_path + 'pangenes.faa'
    new_file= ''.join(aa_allele_path + 'pan_genes.faa')
    print(aa_file)
    print(new_file)
    f=open(aa_file,'r')
    f1=open(new_file,'w')
    for seq_record in SeqIO.parse(aa_file, "fasta"):
        
        if seq_record.id not in locus_list:
            #i=i+1
            print(seq_record.id)
            desc=seq_record.description
            #print(desc)
            allele_seq=str(seq_record.seq)
            #print(allele_seq)
            alleles=''.join(['>'+desc + '\n'+ allele_seq+'\n'])
            f1.write(alleles)

f1.close()
#print(i)

# %%
import os
import pandas as pd



#####cloud path
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_paragasseri/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_paragasseri/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lacticaseibacillus_rhamnosus/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lacticaseibacillus_rhamnosus/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Weissella_cibaria/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Weissella_cibaria/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_crispatus/pangenome_alignments/'
#path= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_crispatus/alleleome/'

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Oenococcus_oeni/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Oenococcus_oeni/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Pediococcus_pentosaceus/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Pediococcus_pentosaceus/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Pediococcus_acidilactici/pangenome_alignments/'
#path= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Pediococcus_acidilactici/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_acidophilus/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_acidophilus/alleleome/' 
 
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Ligilactobacillus_ruminis/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Ligilactobacillus_ruminis/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lacticaseibacillus_paracasei/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lacticaseibacillus_paracasei/alleleome/'

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_gasseri/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_gasseri/alleleome/' 
 
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Levilactobacillus_brevis/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Levilactobacillus_brevis/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_delbrueckii/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_delbrueckii/alleleome/'

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Latilactobacillus_sakei/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Latilactobacillus_sakei/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lentilactobacillus_parabuchneri/pangenome_alignments/'
#path= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lentilactobacillus_parabuchneri/alleleome/'
 
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Limosilactobacillus_reuteri/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Limosilactobacillus_reuteri/alleleome/'

#MAIN_DIR= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Leuconostoc_inhae/pangenome_alignments/'
#path= '/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Leuconostoc_inhae/alleleome/'
 
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Leuconostoc_mesenteroides/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Leuconostoc_mesenteroides/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_johnsonii/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_johnsonii/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactiplantibacillus_pentosus/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactiplantibacillus_pentosus/alleleome/'
  

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Ligilactobacillus_salivarius/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Ligilactobacillus_salivarius/alleleome/' 

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_iners/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Lactobacillus_iners/alleleome/'

#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Weissella_confusa/pangenome_alignments/'
#path='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/Weissella_confusa/alleleome/' 
 
MAIN_DIR='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/pangenome_alignments/'
path='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/Lactobacillus_helveticus/alleleome/'

####for core genes
# Dataframe of core genes
df=pd.read_csv(path + 'df_pangene_summary_v2.csv')
core_gene_list = (df['pangenome_class_2'].eq('Core').groupby(df['Gene']).any()).pipe(lambda x:x.index[x].tolist())
print(core_gene_list)


#dataframe of core gene alleles with genes not satisfying the condition to be removed

df1=pd.read_csv(path + 'core_alleles_with_length_less_than_2std_less_than_mean_length.csv')
print(df1.head())


edit_list=df1['Gene'].to_list()

new_gene_list=set(edit_list)

print(new_gene_list)
print(len(new_gene_list))
print(core_gene_list)
print(len(core_gene_list))


for f in core_gene_list:
    print(f)
    if f not in new_gene_list:
        print(f)
        aa_allele_path = MAIN_DIR + f + '/input/' 
        aa_file=  aa_allele_path + 'pangenes.faa'
        new_file= aa_allele_path + 'pan_genes.faa'
        os.rename(*(os.path.join(aa_allele_path, fname) for fname in (aa_file, new_file)))

# %%
import pandas as pd
import os
import random
import pathlib

import os
from os.path import join, getsize

#######cloud path
#MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/'
MAIN_DIR='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/data/data1/pan_gene/Lactobacillus/'

#######
#species_list=['Lactobacillus_paragasseri', 'Lacticaseibacillus_rhamnosus', 'Weissella_cibaria', 'Lactobacillus_crispatus', 'Oenococcus_oeni', 'Pediococcus_pentosaceus', 'Pediococcus_acidilactici', 'Lactobacillus_acidophilus', 'Ligilactobacillus_ruminis', 'Lacticaseibacillus_paracasei', 'Lactobacillus_gasseri', 'Levilactobacillus_brevis', 'Lactobacillus_delbrueckii', 'Latilactobacillus_sakei', 'Lentilactobacillus_parabuchneri', 'Limosilactobacillus_reuteri', 'Leuconostoc_inhae', 'Leuconostoc_mesenteroides', 'Lactobacillus_johnsonii', 'Lactiplantibacillus_pentosus', 'Ligilactobacillus_salivarius', 'Lactobacillus_iners', 'Weissella_confusa', 'Limosilactobacillus_fermentum']
species_list=['Lactobacillus_helveticus']
print(species_list)
print(len(species_list))


j=0

for k in species_list:
	print(k)
	MAIN_DIR_1= MAIN_DIR + k + '/pangenome_alignments/'
	print(MAIN_DIR_1)
	query_list_1=[name for name in os.listdir(MAIN_DIR_1) if os.path.isdir(os.path.join(MAIN_DIR_1, name))]
	#print(query_list_1)
	for i in query_list_1:
		print(i)
		root_dir = os.path.join(MAIN_DIR_1 + i +'/')
		print('Here is path',root_dir)
		dir="output"
		path = os.path.join(root_dir, dir)
		print('here is new path', path)
		j=j+1
		print(j)
		os.makedirs(path)

# %%
#Amino acids


import pandas as pd
import os
from Bio import AlignIO
from pathlib import Path
from Bio.Align import AlignInfo
from Bio import SeqIO
from Bio.Blast import NCBIWWW
import stat
from Bio.Blast import NCBIXML
from Bio import SearchIO
import numpy as np
import timeit
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Align.Applications import MafftCommandline
from Bio.Align.Applications import MuscleCommandline
import subprocess
from io import StringIO
from Bio import AlignIO
import collections
from collections import Counter
import sys
import pandas as pd

### start statement for time calculation
start=timeit.default_timer()
#####___________________________#######################

######cloud path
MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/'


#Build consensus for sequences with equal or unequal lengths

j=0

species_list=['Lactobacillus_paragasseri', 'Lacticaseibacillus_rhamnosus', 'Weissella_cibaria', 'Lactobacillus_crispatus', 'Oenococcus_oeni', 'Pediococcus_pentosaceus', 'Pediococcus_acidilactici', 'Lactobacillus_acidophilus', 'Ligilactobacillus_ruminis', 'Lacticaseibacillus_paracasei', 'Lactobacillus_gasseri', 'Levilactobacillus_brevis', 'Lactobacillus_delbrueckii', 'Latilactobacillus_sakei', 'Lentilactobacillus_parabuchneri', 'Limosilactobacillus_reuteri', 'Leuconostoc_inhae', 'Leuconostoc_mesenteroides', 'Lactobacillus_johnsonii', 'Lactiplantibacillus_pentosus', 'Ligilactobacillus_salivarius', 'Lactobacillus_iners', 'Weissella_confusa', 'Limosilactobacillus_fermentum']
print(species_list)
print(len(species_list))



# for getting consensus sequence of amino sequences of ORFs
for i in species_list:
    print(i)
    MAIN_DIR_1= MAIN_DIR + i + '/alleleome/'
    #print(MAIN_DIR_1)
    MAIN_DIR_2= MAIN_DIR + i + '/pangenome_alignments/'

    df=pd.read_csv(MAIN_DIR_1 + 'df_pangene_summary_v2.csv')
    core_aa_query_list = (df['pangenome_class_2'].eq('Core').groupby(df['Gene']).any()).pipe(lambda x:x.index[x].tolist())
    #print(len(core_aa_query_list))
    for k in core_aa_query_list:
        #print(k)
        aa_allele_file = MAIN_DIR_2 + k + '/input/' 
        aa_file=  aa_allele_file + 'pan_genes.faa'
        #print(aa_file)
        
        if os.stat(aa_file).st_size == 0:
            print("The file is empty")
            pass
        else:
            mafft_cline = MafftCommandline(input=aa_file)
            #muscle_cline = MuscleCommandline(input=aa_file)

            stdout, stderr = mafft_cline()
            #stdout, stderr = muscle_cline()

            #change path here###########################################
            mafft_out_file=''.join(MAIN_DIR_2+ k +'/output/'+ 'mafft_thresh_aa_' + k +'.fasta' )

            with open(mafft_out_file, "w") as handle:
                handle.write(stdout)
            myalign = AlignIO.read(mafft_out_file, "fasta")
            summary = AlignInfo.SummaryInfo(myalign)
            consensus = summary.dumb_consensus(threshold=0.5)
            #print (consensus)
            seq=str(consensus)
            seq=seq.upper()
        

            consensus_aa_file = os.path.join(MAIN_DIR_2 + k + '/input/'+ 'consensus_nuc_thresh'+ k +'.faa')
            #print(consensus_allele_file)
            consensus_aa = open(consensus_aa_file, 'w+')
            consensus_seq= ''.join(['>' + k +'\n'+ seq])
        
            #print(message, "The consensus sequence is ",consensus_seq)
            consensus_aa.write(consensus_seq)
            consensus_aa.close()
            #print(summary)


### end statement for time calculation_____________________##################
stop=timeit.default_timer()
print('Time: ', stop-start)    
#####

# %%
import pandas as pd
import os
import random
import pathlib
from os.path import join, getsize


######cloud path
MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/'
#MAIN_DIR='/home/azureuser/datadrive/data/data1/data_processing_nuc_aa_code/group/'

species_list=['Lactobacillus_paragasseri', 'Lacticaseibacillus_rhamnosus', 'Weissella_cibaria', 'Lactobacillus_crispatus', 'Oenococcus_oeni', 'Pediococcus_pentosaceus', 'Pediococcus_acidilactici', 'Lactobacillus_acidophilus', 'Ligilactobacillus_ruminis', 'Lacticaseibacillus_paracasei', 'Lactobacillus_gasseri', 'Levilactobacillus_brevis', 'Lactobacillus_delbrueckii', 'Latilactobacillus_sakei', 'Lentilactobacillus_parabuchneri', 'Limosilactobacillus_reuteri', 'Leuconostoc_inhae', 'Leuconostoc_mesenteroides', 'Lactobacillus_johnsonii', 'Lactiplantibacillus_pentosus', 'Ligilactobacillus_salivarius', 'Lactobacillus_iners', 'Weissella_confusa', 'Limosilactobacillus_fermentum']
print(species_list)
print(len(species_list))
#species_list=['Weissella_cibaria','Lactobacillus_paragasseri']
#print(species_list)
#print(len(species_list))



# for getting consensus sequence of amino sequences of ORFs
for i in species_list:
    print(i)
    MAIN_DIR_1= MAIN_DIR + i + '/alleleome/'
    #print(MAIN_DIR_1)
    MAIN_DIR_2= MAIN_DIR + i + '/pangenome_alignments/'

    df=pd.read_csv(MAIN_DIR_1 + 'df_pangene_summary_v2.csv')
    core_aa_query_list = (df['pangenome_class_2'].eq('Core').groupby(df['Gene']).any()).pipe(lambda x:x.index[x].tolist())
    #print(len(core_aa_query_list))

    import subprocess
    blast_path='/home/azureuser/datadrive/ncbi-blast-2.13.0+/bin/blastp'
    #blastp_path = '/usr/local/ncbi/blast/bin/blastp'
    #i=0

    for r in range(len(core_aa_query_list)):
        query=core_aa_query_list[r]
        print(query)
        if (pd.isnull(query)==False):
            out_file_name = MAIN_DIR_2 + query + '/output/' + 'amino_acid_' + 'blast_out_thresh' + query + '.xml'
            print(out_file_name)
            #i=i+1
            #print(i)
            args = (blast_path,
                    '-query', MAIN_DIR_2 + query + '/input/'+'pan_genes.faa',
                    '-subject', MAIN_DIR_2 + query + '/input/'+ 'consensus_aa_thresh'+ query +'.faa' ,
                    '-outfmt', '5',
                )
            with open(out_file_name, 'w+') as outfile:
                subprocess.run(args, stdout=outfile)

# %%
# Patrick code modification for parsing results and generating mutations


import pandas as pd
import numpy as np
import os
import timeit

start=timeit.default_timer()

###########

###########
MAIN_DIR='/home/azureuser/datadrive/data/data1/Lactobacillus_alleleome/'
#####demo
#MAIN_DIR='/Users/arcsan/Documents/allele_from_pan_genome_data_analysis/aa_cons_allele_alleleome_scripts/data_processing_scripts/group/'

species_list=[ 'Lactobacillus_crispatus', 'Ligilactobacillus_ruminis', 'Lacticaseibacillus_paracasei', 'Lactobacillus_delbrueckii', 'Leuconostoc_mesenteroides', 'Lactobacillus_johnsonii', 'Lactiplantibacillus_pentosus', 'Ligilactobacillus_salivarius',  'Weissella_confusa']
print(species_list)
print(len(species_list))
##############


# String parsing helper functions

# fast find all chars in string: https://stackoverflow.com/questions/52452911/finding-all-positions-of-a-character-in-a-string
def _find_all_idx(string, character):
    idx = string.find(character)
    while idx != -1:
        yield idx
        idx = string.find(character, idx + 1)
        

def _get_char_idxs_in_str(s, c):
    char_idxs = list(_find_all_idx(s, c))
    char_idxs = [x for x in char_idxs]
    return char_idxs
    

CHAR_OF_INTEREST = '-'
assert(_get_char_idxs_in_str('AR-D-G', CHAR_OF_INTEREST)==[2,4])



# BLAST results glossary: https://www.ncbi.nlm.nih.gov/books/NBK62051/
# Description of special characters on the match string: https://blast.ncbi.nlm.nih.gov/Blast.cgi?CMD=Web&PAGE_TYPE=BlastDocs&DOC_TYPE=BlastHelp
# The databases alignments are displayed as pairs of matches between query and subject sequence.
# A middle line between the query and subject sequence displays the status of a letter.
# For protein alignments (e.g, BLASTP/BLASTX/TBLASTN), identities present the letter,
# conservative substitutions present a "+", and nothing otherwise. This is the default view.
# https://www.ncbi.nlm.nih.gov/books/NBK62051/: "If the aligned residues have similar physico-chemical properties or have a
# positive score in the governing scoring matrix the substitution is said to be conservative."
# '-' in subject string indicate an insertion

# BLAST subject and query results string are always the same length.


# Won't find differences in the beginning of genes since doesn't compare query vs subject start and end match positions.
# This logic was removed since alleles can have enormous differences on either of their sequences.

# Best to keep the returned data seperate for finding
# consecutive mutations according to AA positions.
from Bio import pairwise2
from Bio.Seq import Seq
from Bio.pairwise2 import format_alignment

BLAST_INDEL_CHAR = '-'
def _get_ins_d(subject_str, query_str, subject_match_start_pos):
    ins_d = dict()
    for idx in _get_char_idxs_in_str(subject_str, BLAST_INDEL_CHAR):
        pos = idx+subject_match_start_pos
        ins_d[pos] = query_str[idx]
    return ins_d

# Won't find differences in the beginning of genes since doesn't compare query vs subject start and end match positions.
def _get_del_d(subject_str, query_str, subject_match_start_pos):
    del_d = dict()
    for idx in _get_char_idxs_in_str(query_str, BLAST_INDEL_CHAR):
        pos = idx+subject_match_start_pos
        del_d[pos] = subject_str[idx]
    return del_d
    
sbjct = 'AR-D-G'  # insertion @ 3 and 5
qry = '-RBDHG'  # deletion @ 1
assert(_get_ins_d(sbjct, qry, 1)=={3: 'B', 5: 'H'})
assert(_get_ins_d(sbjct, qry, 2)=={4: 'B', 6: 'H'})  # test effects of subject_match_start_pos

assert(_get_del_d(sbjct, qry, 1)=={1: 'A'})
assert(_get_del_d(sbjct, qry, 2)=={2: 'A'})  # test effects of subject_match_start_pos


ALL_AMINO_ACIDS = {'A','R','N','D','B','C','E','Q','Z','G','H','I','L','K','M','F','P','S','T','W','Y','V'}

def _get_sub_aa_d(subject_str, match_str, query_str, indel_aa_pos_l, subject_match_start_pos):
    seq_chng_d = dict()
    
    for c_i in range(0, len(match_str)):
        if match_str[c_i] not in ALL_AMINO_ACIDS:  # finding BLAST characters indicating mismatch or gap
            pos = subject_match_start_pos+c_i  # subject_match_start_pos+c_i since subject_match_start_pos represents the first charater and the index c_i == 0
            if pos not in indel_aa_pos_l:
                seq_chng_d[pos] = {'s':subject_str[c_i], 'q':query_str[c_i]}
    
    return seq_chng_d



assert(_get_sub_aa_d('ARPGCQ', '+ PG Q', 'MTPGBQ', [], 1)=={1: {'s':'A', 'q':'M'}, 2: {'s':'R', 'q':'T'}, 5: {'s':'C', 'q':'B'}})
assert(_get_sub_aa_d('ARPGCQ', '+ PG Q', 'MTPGBQ', [5], 1)=={1: {'s':'A', 'q':'M'}, 2: {'s':'R', 'q':'T'}})  # testing use of indel_aa_pos_l
assert(_get_sub_aa_d('ARPGCQ', '+ PG Q', 'MTPGBQ', [], 2)=={2: {'s':'A', 'q':'M'}, 3: {'s':'R', 'q':'T'}, 6: {'s':'C', 'q':'B'}})  # test effects of subject_match_start_pos



from itertools import groupby
from operator import itemgetter


def _get_consecutive_pos_l(pos_l):
    cnsc_pos_l = []
    for k, g in groupby(enumerate(pos_l), lambda ix : ix[0] - ix[1]):
        cnsc_pos_l.append(list(map(itemgetter(1), g)))
    return cnsc_pos_l

mut_pos_l = [1, 4,5, 7,8,9, 22]
assert(_get_consecutive_pos_l(mut_pos_l)==[[1], [4, 5], [7, 8, 9], [22]])




import glob
from Bio.Blast import NCBIXML
#i=0
gene_var_df = pd.DataFrame()

for i in species_list:
    print(i)
    MAIN_DIR_1= MAIN_DIR + i + '/alleleome/'
    #print(MAIN_DIR_1)
    MAIN_DIR_2= MAIN_DIR + i + '/pangenome_alignments/'

    df=pd.read_csv(MAIN_DIR_1 + 'df_pangene_summary_v2.csv')
    core_aa_query_list = (df['pangenome_class_2'].eq('Core').groupby(df['Gene']).any()).pipe(lambda x:x.index[x].tolist())
    #print(len(core_aa_query_list))

    for blast_output_file in core_aa_query_list:
        blast_file_name= MAIN_DIR_2 + blast_output_file + '/output/'
        print(blast_file_name)
        blast_output_file_path = blast_file_name + 'amino_acid_blast_out_thresh'+ blast_output_file + '.xml'
        print(blast_output_file_path)
        gene = blast_output_file.replace(blast_file_name,'').replace('.xml','')
    
        for record in NCBIXML.parse(open(blast_output_file_path)):
            if len(record.alignments) > 0:
                #Description of available members: https://biopython.org/docs/1.75/api/Bio.Blast.Record.html
                subject_match_start_pos = record.alignments[0].hsps[0].sbjct_start
                blast_subject_str = record.alignments[0].hsps[0].sbjct
                #print("This is subject sequence",i,  blast_subject_str)
                #print(len(blast_subject_str))
                #i=i+1
                blast_match_str = record.alignments[0].hsps[0].match
                blast_query_str = record.alignments[0].hsps[0].query
                length_align = record.alignments[0].hsps[0].align_length
                align_score = record.alignments[0].hsps[0].score
                num_align= record.alignments[0].hsps[0].num_alignments
                e_value=record.alignments[0].hsps[0].expect
                num_indentities= record.alignments[0].hsps[0].identities
                ref_id= record.alignments[0].hit_id
                #print("This is query sequence", blast_query_str)
                #print(len(blast_query_str))
                ref_info= record.alignments[0].hit_def # new added#### column name to be added####
                #ref_info=ref_info.split(" ", 1)
                print(ref_info)
                query_info= record.query
                query_info=query_info.split("|", 1)
                print(query_info)
                query_description=query_info[0]
                query_description=query_description.split(" ", 1)
                print(query_description)
                query_id=query_description[0]
                print(query_id)
                query_desc=query_description[1]
                print(query_desc)
                GCF_id=query_info[1]
                print(GCF_id)

                # Won't find differences in the beginning of genes since doesn't compare query vs subject start and end match positions.
                ins_d = _get_ins_d(blast_subject_str, blast_query_str, subject_match_start_pos)
                for cnsc_pos_l in _get_consecutive_pos_l(ins_d.keys()):
                    seq_chng_str = ''.join([ins_d[p] for p in cnsc_pos_l])
                    df = pd.DataFrame.from_dict({
                        'Gene': gene,
                        "Mutation_source": "Pangenome variant",
                        "AA_start_pos": min(cnsc_pos_l),
                        "AA_end_pos" : max(cnsc_pos_l),
                        "Mutation_size": len(cnsc_pos_l),
                        "AA_mutation_type": "Insertion",
                        'AA_cons_seq': '',
                        "AA_seq_change": seq_chng_str,
                        "Length_alignment": length_align,
                        "Score" : align_score,
                        "E_value": e_value,
                        "Identity" : num_indentities,
                        "Query_locus_tag" : query_id,
                        "Query_description" : query_desc,
                        "GCF_id" : GCF_id,
                        "Sequence_type": "Variant",

                    }, orient='index')  # Can't use columns due to diff parsing of 'AA range' input
                    df = df.T
                    gene_var_df = pd.concat([df, gene_var_df]) # Accounting for multiples of same allele
            
                # Won't find differences in the beginning of genes since doesn't compare query vs subject start and end match positions.
                del_d = _get_del_d(blast_subject_str, blast_query_str, subject_match_start_pos)
                for cnsc_pos_l in _get_consecutive_pos_l(del_d.keys()):
                    seq_chng_str = ''.join([del_d[p] for p in cnsc_pos_l])
                    df = pd.DataFrame.from_dict({
                            'Gene': gene,
                            "Mutation_source": "Pangenome variant",
                            "AA_start_pos": min(cnsc_pos_l),
                            "AA_end_pos" : max(cnsc_pos_l),
                            "Mutation_size": len(cnsc_pos_l),
                            "AA_mutation_type": "Deletion",
                            'AA_cons_seq': seq_chng_str,
                            "AA_seq_change": '',
                            "Length_alignment": length_align,
                            "Score" : align_score,
                            "E_value": e_value,
                            "Identity" : num_indentities,
                            "Query_locus_tag" : query_id,
                            "Query_description" : query_desc,
                            "GCF_id" : GCF_id,
                            "Sequence_type": "Variant",

                    }, orient='index')  # Can't use columns due to diff parsing of 'AA range' input
                    df = df.T
                    gene_var_df = pd.concat([df, gene_var_df]) # Accounting for multiples of same allele
                
                sub_d = _get_sub_aa_d(
                        blast_subject_str,
                        blast_match_str,
                        blast_query_str,
                list(ins_d.keys()) + list(del_d.keys()),
                subject_match_start_pos)
            
                for cnsc_pos_l in _get_consecutive_pos_l(sub_d.keys()):
                    seq_ref_str = ''.join([sub_d[p]['s'] for p in cnsc_pos_l])
                    seq_chng_str = ''.join([sub_d[p]['q'] for p in cnsc_pos_l])
                    df = pd.DataFrame.from_dict({
                            'Gene': gene,
                            "Mutation_source": "Pangenome variant",
                            "AA_start_pos": min(cnsc_pos_l),
                            "AA_end_pos" : max(cnsc_pos_l),
                            "Mutation_size": len(cnsc_pos_l),
                            "AA_mutation_type": "Substitution",
                            'AA_cons_seq': seq_ref_str,
                            "AA_seq_change": seq_chng_str,
                            "Length_alignment": length_align,
                            "Score" : align_score,
                            "E_value": e_value,
                            "Identity" : num_indentities,
                            "Query_locus_tag" : query_id,
                            "Query_description" : query_desc,
                            "GCF_id" : GCF_id,
                            "Sequence_type": "Variant",

                    }, orient='index')  # Can't use columns due to diff parsing of 'AA range' input
                    df = df.T
                    gene_var_df = pd.concat([df, gene_var_df]) # Accounting for multiples of same allele

        print(gene_var_df.head())
        gene_var_df.to_csv(os.path.join(MAIN_DIR_1,'pan_aa_gene_vars_df'  + '.csv'))          

stop=timeit.default_timer()
print('Time: ', stop-start)
